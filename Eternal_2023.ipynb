# %% [markdown]
# # **----------------DAY-WISE PREDICTION-------------------**

# %% [markdown]
# # **OLDEST DATA PREDICTION FROM 1973**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_d.csv")
print(data.head())
# Out:
#          Date  Open  High   Low  Close
# 0  1973-01-02  8.02  8.02  8.02   8.02
# 1  1973-01-03  8.02  8.02  8.02   8.02
# 2  1973-01-04  8.00  8.00  8.00   8.00
# 3  1973-01-05  8.01  8.01  8.01   8.01
# 4  1973-01-08  8.00  8.00  8.00   8.00

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.999994  0.999994  0.999990
# High   0.999994  1.000000  0.999990  0.999995
# Low    0.999994  0.999990  1.000000  0.999995
# Close  0.999990  0.999995  0.999995  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data)
# Out:
#       Predicted Rate
# 0             47.505
# 1              8.030
# 2             48.769
# 3             48.305
# 4             45.940
# ...              ...
# 2505           8.620
# 2506           7.940
# 2507           8.930
# 2508          58.770
# 2509          35.443
#
# [2510 rows x 1 columns]

# %% [markdown]
# # **OLD DATA PREDICTION FROM 1983**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_d (4).csv")
print(data.head())
# Out:
#          Date  Open  High   Low  Close
# 0  1983-01-03  9.62  9.62  9.62   9.62
# 1  1983-01-04  9.64  9.64  9.64   9.64
# 2  1983-01-05  9.64  9.64  9.64   9.64
# 3  1983-01-06  9.70  9.70  9.70   9.70
# 4  1983-01-07  9.73  9.73  9.73   9.73

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.999990  0.999991  0.999984
# High   0.999990  1.000000  0.999985  0.999992
# Low    0.999991  0.999985  1.000000  0.999992
# Close  0.999984  0.999992  0.999992  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0           9.980
# 1          41.040
# 2          45.270
# 3          64.855
# 4          31.436

# %% [markdown]
# # **OLD DATA PPREDICTION FROM 2000**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_d (2).csv")
print(data.head())
# Out:
#          Date   Open   High    Low  Close
# 0  2000-01-03  43.42  43.42  43.42  43.42
# 1  2000-01-04  43.41  43.41  43.41  43.41
# 2  2000-01-05  43.44  43.44  43.44  43.44
# 3  2000-01-06  43.43  43.43  43.43  43.43
# 4  2000-01-07  43.42  43.42  43.42  43.42

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.999957  0.999961  0.999926
# High   0.999957  1.000000  0.999940  0.999965
# Low    0.999961  0.999940  1.000000  0.999965
# Close  0.999926  0.999965  0.999965  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         54.8000
# 1         66.7450
# 2         43.3500
# 3         52.3700
# 4         69.6925

# %% [markdown]
# # **NEW DATA PREDICTION FROM 2010**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_d (5).csv")
print(data.head())
# Out:
#          Date   Open   High    Low  Close
# 0  2010-01-04  46.48  46.53  46.29  46.31
# 1  2010-01-05  46.23  46.25  46.08  46.19
# 2  2010-01-06  46.09  46.19  45.92  45.92
# 3  2010-01-07  45.78  45.88  45.54  45.66
# 4  2010-01-08  45.79  45.88  45.72  45.81

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.999925  0.999935  0.999862
# High   0.999925  1.000000  0.999910  0.999942
# Low    0.999935  0.999910  1.000000  0.999941
# Close  0.999862  0.999942  0.999941  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         49.5200
# 1         68.7200
# 2         45.3300
# 3         79.6605
# 4         67.9868

# %% [markdown]
# # **NEW DATA PPREDICTION FROM 2016**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_d (6).csv")
print(data.head())
# Out:
#          Date     Open     High     Low   Close
# 0  2016-01-04  66.3750  66.5875  66.375  66.580
# 1  2016-01-05  66.4450  66.6500  66.440  66.615
# 2  2016-01-06  66.7050  66.8600  66.655  66.805
# 3  2016-01-07  66.9200  66.9350  66.670  66.895
# 4  2016-01-08  66.6425  66.7750  66.630  66.670

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.999721  0.999760  0.999452
# High   0.999721  1.000000  0.999715  0.999804
# Low    0.999760  0.999715  1.000000  0.999777
# Close  0.999452  0.999804  0.999777  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0          64.335
# 1          64.175
# 2          64.250
# 3          64.415
# 4          76.459

# %% [markdown]
# # **NEWEST DATA PPREDICTION FROM 2023**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_d (3).csv")
print(data.head())
# Out:
#          Date     Open     High      Low    Close
# 0  2023-01-02  82.6275  82.7925  82.5925  82.7862
# 1  2023-01-03  82.7655  83.0850  82.7362  83.0125
# 2  2023-01-04  82.8755  82.9175  82.7325  82.8050
# 3  2023-01-05  82.7775  82.7815  82.4295  82.4775
# 4  2023-01-06  82.6575  82.7605  82.6065  82.7375

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.980592  0.974641  0.951851
# High   0.980592  1.000000  0.979033  0.981340
# Low    0.974641  0.979033  1.000000  0.988718
# Close  0.951851  0.981340  0.988718  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         82.8262
# 1         82.4885
# 2         82.7100
# 3         82.5325
# 4         82.7100

# %% [markdown]
# # **----------------MONTH-WISE PREDICTION-------------------**

# %% [markdown]
# # **OLDEST DATA PREDICTION FROM 1973**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_m (1).csv")
print(data.head())
# Out:
#          Date  Open  High   Low  Close
# 0  1973-01-31  8.02  8.02  8.00   8.00
# 1  1973-02-28  8.00  8.01  7.52   7.52
# 2  1973-03-31  7.55  7.94  7.19   7.55
# 3  1973-04-30  7.58  7.58  7.50   7.53
# 4  1973-05-31  7.54  7.55  7.35   7.39

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.999539  0.999753  0.999335
# High   0.999539  1.000000  0.999440  0.999742
# Low    0.999753  0.999440  1.000000  0.999641
# Close  0.999335  0.999742  0.999641  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0          9.3900
# 1         67.4300
# 2         75.5634
# 3          7.9700
# 4         13.0000

# %% [markdown]
# # **OLD DATA PREDICTION FROM 1983**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_m.csv")
print(data.head())
# Out:
#          Date   Open   High   Low  Close
# 0  1983-01-31   9.62   9.91  9.62   9.91
# 1  1983-02-28   9.92   9.98  9.85   9.96
# 2  1983-03-31   9.98  10.00  9.92  10.00
# 3  1983-04-30  10.00  10.00  9.94  10.00
# 4  1983-05-31  10.00  10.00  9.90   9.98

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.999269  0.999610  0.998948
# High   0.999269  1.000000  0.999114  0.999594
# Low    0.999610  0.999114  1.000000  0.999431
# Close  0.998948  0.999594  0.999431  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         65.3275
# 1         79.4555
# 2         39.1000
# 3         71.5400
# 4         39.6880

# %% [markdown]
# # **OLD DATA PPREDICTION FROM 2000**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_m (2).csv")
print(data.head())
# Out:
#          Date    Open   High    Low  Close
# 0  2000-01-31  43.420  43.60  43.41  43.55
# 1  2000-02-29  43.590  43.60  43.52  43.55
# 2  2000-03-31  43.550  43.59  43.50  43.55
# 3  2000-04-30  43.592  43.63  43.54  43.60
# 4  2000-05-31  43.620  44.50  43.55  44.50

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.997136  0.998402  0.995754
# High   0.997136  1.000000  0.996686  0.998462
# Low    0.998402  0.996686  1.000000  0.997811
# Close  0.995754  0.998462  0.997811  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         48.7580
# 1         46.3640
# 2         66.8350
# 3         50.8600
# 4         72.9036

# %% [markdown]
# # **NEW DATA PREDICTION FROM 2010**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_m (3).csv")
print(data.head())
# Out:
#          Date   Open   High    Low  Close
# 0  2010-01-31  46.48  46.53  45.28  46.22
# 1  2010-02-28  46.34  46.86  45.94  46.13
# 2  2010-03-31  46.05  46.09  44.89  44.96
# 3  2010-04-30  44.92  44.93  44.22  44.41
# 4  2010-05-31  44.58  47.75  44.48  46.46

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.994580  0.997375  0.991718
# High   0.994580  1.000000  0.994800  0.997128
# Low    0.997375  0.994800  1.000000  0.996260
# Close  0.991718  0.997128  0.996260  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         66.7200
# 1         82.5775
# 2         73.1050
# 3         61.3700
# 4         64.7650

# %% [markdown]
# # **NEW DATA PPREDICTION FROM 2016**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_m (4).csv")
print(data.head())
# Out:
#          Date     Open    High     Low    Close
# 0  2016-01-31  66.3750  68.220  66.375  67.8700
# 1  2016-02-29  67.6475  68.780  67.590  68.4200
# 2  2016-03-31  68.3000  68.300  66.170  66.2525
# 3  2016-04-30  66.3375  66.840  66.070  66.4850
# 4  2016-05-31  66.3200  67.745  66.230  67.1700

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.987932  0.991293  0.976106
# High   0.987932  1.000000  0.990364  0.992066
# Low    0.991293  0.990364  1.000000  0.990803
# Close  0.976106  0.992066  0.990803  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         76.4175
# 1         66.6125
# 2         64.7650
# 3         64.7650
# 4         67.8700

# %% [markdown]
# # **NEWEST DATA PPREDICTION FROM 2023**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_m (5).csv")
print(data.head())
# Out:
#          Date     Open     High      Low    Close
# 0  2023-01-31  82.6275  83.0850  81.0745  81.9305
# 1  2023-02-28  81.8765  82.9365  81.6788  82.5775
# 2  2023-03-31  82.5025  82.6255  81.9175  81.9685

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000 -0.045439 -0.390615 -0.994638
# High  -0.045439  1.000000 -0.901854  0.148503
# Low   -0.390615 -0.901854  1.000000  0.293323
# Close -0.994638  0.148503  0.293323  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         82.5775

# %% [markdown]
# # **----------------QUARTER-WISE PREDICTION-------------------**

# %% [markdown]
# # **OLD DATA PREDICTION FROM 1973**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_q.csv")
print(data.head())
# Out:
#          Date  Open  High   Low  Close
# 0  1973-03-31  8.02  8.02  7.19   7.55
# 1  1973-06-30  7.58  7.58  7.22   7.30
# 2  1973-09-30  7.30  7.78  7.25   7.75
# 3  1973-12-31  7.72  8.20  7.68   8.16
# 4  1974-03-31  8.16  8.62  7.81   7.81

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.998485  0.999560  0.998221
# High   0.998485  1.000000  0.998468  0.999397
# Low    0.999560  0.998468  1.000000  0.998836
# Close  0.998221  0.999397  0.998836  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0          35.444
# 1           8.970
# 2           7.870
# 3          54.790
# 4          43.512

# %% [markdown]
# # **OLD DATA PREDICTION FROM 1983**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_q (1).csv")
print(data.head())
# Out:
#          Date   Open  High    Low  Close
# 0  1983-03-31   9.62  10.0   9.62   10.0
# 1  1983-06-30  10.00  10.1   9.90   10.0
# 2  1983-09-30  10.00  10.2  10.00   10.2
# 3  1983-12-31  10.20  10.6  10.10   10.4
# 4  1984-03-31  10.50  10.7  10.50   10.7

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.997596  0.999315  0.997194
# High   0.997596  1.000000  0.997565  0.999050
# Low    0.999315  0.997565  1.000000  0.998150
# Close  0.997194  0.999050  0.998150  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         50.8600
# 1         45.6520
# 2         70.7075
# 3         35.7570
# 4         46.5100

# %% [markdown]
# # **OLD DATA PPREDICTION FROM 2000**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_q (2).csv")
print(data.head())
# Out:
#          Date    Open    High    Low   Close
# 0  2000-03-31  43.420  43.600  43.41  43.550
# 1  2000-06-30  43.592  44.700  43.54  44.600
# 2  2000-09-30  44.600  46.250  44.60  45.900
# 3  2000-12-31  45.970  46.830  45.95  46.610
# 4  2001-03-31  46.660  46.713  46.29  46.607

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.991109  0.997183  0.989145
# High   0.991109  1.000000  0.991340  0.996475
# Low    0.997183  0.991340  1.000000  0.993225
# Close  0.989145  0.996475  0.993225  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         47.0120
# 1         43.5120
# 2         63.1300
# 3         63.8225
# 4         43.6800

# %% [markdown]
# # **NEW DATA PREDICTION FROM 2010**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_q (3).csv")
print(data.head())
# Out:
#          Date   Open   High    Low  Close
# 0  2010-03-31  46.48  46.86  44.89  44.96
# 1  2010-06-30  44.92  47.75  44.22  46.48
# 2  2010-09-30  46.73  47.35  44.83  44.83
# 3  2010-12-31  44.70  46.10  43.98  44.68
# 4  2011-03-31  44.69  46.00  44.50  44.56

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.984219  0.996191  0.980967
# High   0.984219  1.000000  0.987305  0.993799
# Low    0.996191  0.987305  1.000000  0.988778
# Close  0.980967  0.993799  0.988778  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         61.7300
# 1         78.9955
# 2         75.7750
# 3         52.6600
# 4         74.2225

# %% [markdown]
# # **NEW DATA PPREDICTION FROM 2016**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/usdinr_q (4).csv")
print(data.head())
# Out:
#          Date     Open     High      Low    Close
# 0  2016-03-31  66.3750  68.7800  66.1700  66.2525
# 1  2016-06-30  66.3375  68.1475  66.0700  67.5300
# 2  2016-09-30  67.4600  67.5025  66.3250  66.6125
# 3  2016-12-31  66.4925  68.8525  66.3599  67.8700
# 4  2017-03-31  67.9625  68.3799  64.8000  64.8475

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.969771  0.987200  0.943327
# High   0.969771  1.000000  0.977012  0.981774
# Low    0.987200  0.977012  1.000000  0.970593
# Close  0.943327  0.981774  0.970593  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0         81.9685
# 1         70.7075
# 2         71.3240
# 3         73.0230
# 4         63.8225
